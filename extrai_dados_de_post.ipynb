# %%
import os
from dotenv import load_dotenv
from funcoes import extrai_dados_post_ig

# Carregamento de Environment Variables para gestão segura de senhas (Secrets Management)
load_dotenv()

# Recuperação de credenciais via variáveis de ambiente para evitar Hardcoding de senhas
USER = os.getenv("IG_USER")
PASS = os.getenv("IG_PASS")
URL = "https://www.instagram.com/p/DWtac3DkU9I/"

# Rodando a função principal e guardando o resultado em uma tabela (DataFrame)
# Execução da pipeline de ingestão de dados com retorno de objeto estruturado (Pandas DF)
df_final = extrai_dados_post_ig(URL, USER, PASS)

# %%
df = extrai_dados_post_ig("https://www.instagram.com/p/DWtac3DkU9I/")
# Out:
# Buscando post público: DWtac3DkU9I...
# JSON Query to graphql/query: 403 Forbidden when accessing https://www.instagram.com/graphql/query [retrying; skip with ^C]
# Extraindo comentários...
# ❌ Erro ao acessar post público: Login required to access comments of a post.
# Dica: Se o erro 403 persistir, o Instagram pode ter bloqueado seu IP temporariamente.
