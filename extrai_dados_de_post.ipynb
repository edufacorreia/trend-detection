# %%
import os
from dotenv import load_dotenv
from funcoes import extrai_dados_post_ig

# Carregamento de Environment Variables para gestão segura de senhas (Secrets Management)
load_dotenv()

# Recuperação de credenciais via variáveis de ambiente para evitar Hardcoding de senhas
USER = os.getenv("IG_USER")
PASS = os.getenv("IG_PASS")
URL = "https://www.instagram.com/p/DWtac3DkU9I/"

# Rodando a função principal e guardando o resultado em uma tabela (DataFrame)
# Execução da pipeline de ingestão de dados com retorno de objeto estruturado (Pandas DF)
df_final = extrai_dados_post_ig(URL, USER, PASS)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      11 URL = "https://www.instagram.com/p/DWtac3DkU9I/"
#      12
#      13 # Rodando a função principal e guardando o resultado em uma tabela (DataFrame)
#      14 # Execução da pipeline de ingestão de dados com retorno de objeto estruturado (Pandas DF)
# ---> 15 df_final = extrai_dados_post_ig(URL, USER, PASS)
#
# File ~/data_science_projects/social_listening/instagram_post/funcoes.py:22, in extrai_dados_post_ig(url_do_post, username, password, salvar_csv)
#      18 FOLDER_NAME = "dados"
#      20 # Configurando o robô com pausas automáticas e um "disfarce" de navegador comum
#      21 # Inicialização da Engine de Scraping com Throttling nativo e User-Agent Spoofing
# ---> 22 L = instaloader.Instaloader(
#      23     sleep_between_interactions=True,
#      24     user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36"
#      25 )
#      27 # Tentando carregar o acesso salvo para não precisar logar toda hora
#      28 # Implementação de Session Persistence para bypass de desafios de Auth e 2FA
#      29 try:
#
# TypeError: Instaloader.__init__() got an unexpected keyword argument 'sleep_between_interactions'

# %%
df_final
# Out:
# Buscando post público: DWtac3DkU9I...
# JSON Query to graphql/query: 403 Forbidden when accessing https://www.instagram.com/graphql/query [retrying; skip with ^C]
# Extraindo comentários...
# ❌ Erro ao acessar post público: Login required to access comments of a post.
# Dica: Se o erro 403 persistir, o Instagram pode ter bloqueado seu IP temporariamente.
